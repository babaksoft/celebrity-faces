# %% [markdown]
# # Experimenting in PyTorch

# %% [markdown]
# ## Environment setup

# %% [markdown]
# ## Experiment 4

# %% [markdown]
# *TODO: Briefly describe experiment here*

# %% [markdown]
# ## Experiment 5

# %% [markdown]
# *TODO: Briefly describe fine-tuning experiment here*
